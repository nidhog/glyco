# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import logging
logging.basicConfig(level=logging.INFO)

# %%
import glyco as gl

gdf = gl.read_csv('../examples/data/.data/t01_cgm.csv', mask_private_info=True, timestamp_fmt='%d-%m-%Y %H:%M', private_info_kwargs={
    'set_start_datetime_at': '01-01-2016 02:30',
    'remove_columns': None,
    'replace_columns': ['Notes'],
    'replace_func': gl.privacy.default_replace_func,
    'noise_std': 0.5
})
print(gdf['tsp'].min())
print(gdf.index.min())
# Out:
# INFO:glyco.privacy:The values of the columns '(Notes)' will be replaced using a hash...
# INFO:glyco.privacy:The min time in the timstamp column 'Device Timestamp' will be shifted to: '01-01-2016 02:30'...
# INFO:glyco.privacy:Adding noise to the glucose data in the column 'Historic Glucose mmol/L'...
# 2016-01-01 04:32:00
# 2016-01-01 04:32:00

# %%
gdf = gl.read_csv('../examples/data/.data/ismail_last.csv', mask_private_info=True)
# Out:
# INFO:glyco.privacy:The values of the columns '(Notes)' will be replaced using a hash...
# INFO:glyco.privacy:The min time in the timstamp column 'Device Timestamp' will be shifted to: '01-01-2023 00:00'...
# INFO:glyco.privacy:Adding noise to the glucose data in the column 'Historic Glucose mmol/L'...
# INFO:glyco.privacy:Removing the following privacy columns: Serial Number...
# 01-01-2023 15:24

# %%
print(gdf['tsp'].min(), gdf.index.min())
# Out:
# 2023-01-01 17:41:00 2023-01-01 17:41:00

# %%
gl.plot_sleep_trends(gdf)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In [133], line 1
# ----> 1 plot_sleep_trends(gdf)
#
# NameError: name 'plot_sleep_trends' is not defined

# %%
gdf.head(3)
# Out:
#                      Unnamed: 0  Device Timestamp  Record Type  \
# idx
# 2023-06-02 17:35:00           4  02-06-2023 17:35            0
# 2023-06-02 17:50:00           5  02-06-2023 17:50            0
# 2023-06-02 18:05:00           6  02-06-2023 18:05            0
#
#                      Historic Glucose mmol/L  Scan Glucose mmol/L  \
# idx
# 2023-06-02 17:35:00                      5.1                  NaN
# 2023-06-02 17:50:00                      4.7                  NaN
# 2023-06-02 18:05:00                      4.9                  NaN
#
#                      Non-numeric Rapid-Acting Insulin  \
# idx
# 2023-06-02 17:35:00                               NaN
# 2023-06-02 17:50:00                               NaN
# 2023-06-02 18:05:00                               NaN
#
#                      Rapid-Acting Insulin (units)  Non-numeric Food  \
# idx
# 2023-06-02 17:35:00                           NaN               NaN
# ...

# %%
gl.plot_glucose

# %%
from glyco.utils import *

# %%
init_plot()
gl.plot_glucose(gdf)
